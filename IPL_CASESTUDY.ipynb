# %% [markdown]
# # Import all libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns

# %% [markdown]
#    # Read ipl.csv file and print first 5 records

# %%
df=pd.read_csv("ipl data.csv")
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# # Check total number of columns,entries note down your findings

# %%
len(df.columns)
# Out:
# 18

# %%
df.size
# Out:
# 11448

# %% [markdown]
# ##### Total colums- 18 and total entries are 11448

# %% [markdown]
# # Find null values

# %%
df.isnull()
# Out:
#         id  season   city   date  team1  team2  toss_winner  toss_decision  \
# 0    False   False  False  False  False  False        False          False
# 1    False   False  False  False  False  False        False          False
# 2    False   False  False  False  False  False        False          False
# 3    False   False  False  False  False  False        False          False
# 4    False   False  False  False  False  False        False          False
# ..     ...     ...    ...    ...    ...    ...          ...            ...
# 631  False   False  False  False  False  False        False          False
# 632  False   False  False  False  False  False        False          False
# 633  False   False  False  False  False  False        False          False
# 634  False   False  False  False  False  False        False          False
# 635  False   False  False  False  False  False        False          False
#
# ...

# %% [markdown]
# # Drop umpire3 column as it contains more than 75% of null values#

# %%
df.drop("umpire3",axis=1,inplace=True)
df.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  2017-04-05          Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06               Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07                Gujarat Lions
# 3   4    2017     Indore  2017-04-08       Rising Pune Supergiant
# 4   5    2017  Bangalore  2017-04-08  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %% [markdown]
# ## Drop null values of city , winner ,player_of_match,umpire1,umpire2 column

# %%
df.dropna(subset=["city", "winner", "player_of_match", "umpire1", "umpire2"], inplace=True)
df.head()
# Out:
#    id  season       city        date                   team1  \
# 0   1    2017  Hyderabad  2017-04-05     Sunrisers Hyderabad
# 1   2    2017       Pune  2017-04-06          Mumbai Indians
# 2   3    2017     Rajkot  2017-04-07           Gujarat Lions
# 3   4    2017     Indore  2017-04-08  Rising Pune Supergiant
# 5   6    2017  Hyderabad  2017-04-09           Gujarat Lions
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 5          Sunrisers Hyderabad          Sunrisers Hyderabad         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# ...

# %% [markdown]
# # which city hosted most number of matches?

# %% [markdown]
# #### draw bar plot and write down your insights

# %%
a= df.groupby("city").count()["id"]
a
b= a.sort_values(ascending=False).index[0]
b
# Out:
# 'Mumbai'

# %% [markdown]
# #### Most matches were played in mumbai(85).

# %% [markdown]
# # draw bar plot and write down your insights

# %%
sns.countplot(x='city',data=df)
plt.title('Most Number of matches hosted in the city',fontsize=20)
plt.xlabel('city',fontsize=15)
plt.ylabel('id',fontsize=15)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ##### According to the stats, Most matches were held in mumbai that are 85 matches.Above bar chart also represents the which city hosted most number of matches

# %% [markdown]
# # Find all venue of mumbai city

# %%
v=df[df["city"] == "Mumbai"]["venue"].unique()
v
# Out:
# array(['Wankhede Stadium', 'Dr DY Patil Sports Academy',
#        'Brabourne Stadium'], dtype=object)

# %% [markdown]
# # now compare in which venue of mumbai most number of matches played (draw bar plot and write down insights)

# %%
c=df[df.city== 'Mumbai']

d= c.groupby('venue')[['id']].count().sort_values('id',ascending=False)[0:]
d
# Out:
#                             id
# venue
# Wankhede Stadium            57
# Dr DY Patil Sports Academy  17
# Brabourne Stadium           11

# %%
d.plot(kind='bar')
plt.xlabel("Venue")
plt.ylabel("Number of Matches")
plt.title("Number of Matches played in different Venues of Mumbai")
plt.show()

# %% [markdown]
# #### By this we come to know that in the venue of mumbai most number of matches played were in Wankhede stadium.

# %% [markdown]
# # What is the preferred choice after winning a toss in mumbai

# %%
f=df[(df["city"] == "Mumbai") & (df["toss_decision"] != "field")] 
g=f["toss_decision"].value_counts()
g
# Out:
# bat    34
# Name: toss_decision, dtype: int64

# %% [markdown]
# # Graphical representation of above question

# %%
g.plot(kind='pie',autopct='%1.1f%%')
plt.title("Preferred choice after winning a toss in Mumbai")
plt.show()

# %%
sns.displot(y='toss_decision',data=df,hue='toss_decision')
plt.title('Decision taken by Captains after winning tosses ' , fontsize =20)
plt.xlabel('Frequency',fontsize=15)
plt.ylabel('toss_decision',fontsize= 15)
plt.show()

# %%
df['toss_decision'].head()
# Out:
# 0    field
# 1    field
# 2    field
# 3    field
# 5    field
# Name: toss_decision, dtype: object

# %% [markdown]
# # Which team won most number of toss

# %%
h= df["toss_winner"].value_counts()
h
# Out:
# Mumbai Indians                 83
# Kolkata Knight Riders          77
# Delhi Daredevils               71
# Royal Challengers Bangalore    67
# Kings XI Punjab                67
# Chennai Super Kings            66
# Rajasthan Royals               61
# Deccan Chargers                43
# Sunrisers Hyderabad            34
# Pune Warriors                  20
# Gujarat Lions                  15
# Kochi Tuskers Kerala            8
# Rising Pune Supergiants         7
# Rising Pune Supergiant          6
# Name: toss_winner, dtype: int64

# %% [markdown]
# ##### Mumbai Indians won most number of toss in the tournament.

# %% [markdown]
# # Show graphical representation of above question

# %%
h.plot(kind='bar')
plt.xlabel("Team")
plt.ylabel("Number of Tosses Won")
plt.title("Number of Tosses won by Teams")
plt.show()

# %% [markdown]
# # Find what mumbai indians preferred after winning a toss?

# %%
i= df[((df["team1"] == "Mumbai Indians") | (df["team2"] == "Mumbai Indians")) & (df["toss_decision"] != "field")]
j= i["toss_decision"].value_counts()
j
# Out:
# bat    69
# Name: toss_decision, dtype: int64

# %% [markdown]
# # Head to head winning count of Mumbai Indians vs Chennai Super Kings

# %%
count= df[((df["team1"] == "Mumbai Indians") & (df["team2"] == "Chennai Super Kings")) |((df["team1"] == "Chennai Super Kings") & (df["team2"] == "Mumbai Indians"))]
count
# Out:
#       id  season            city        date                team1  \
# 66    67    2008         Chennai  2008-04-23  Chennai Super Kings
# 95    96    2008          Mumbai  2008-05-14  Chennai Super Kings
# 117  118    2009       Cape Town  2009-04-18       Mumbai Indians
# 161  162    2009  Port Elizabeth  2009-05-16       Mumbai Indians
# 193  194    2010          Mumbai  2010-03-25  Chennai Super Kings
# 210  211    2010         Chennai  2010-04-06  Chennai Super Kings
# 233  234    2010          Mumbai  2010-04-25  Chennai Super Kings
# 256  257    2011          Mumbai  2011-04-22       Mumbai Indians
# 307  308    2012         Chennai  2012-04-04  Chennai Super Kings
# 354  355    2012          Mumbai  2012-05-06  Chennai Super Kings
# 378  379    2012       Bangalore  2012-05-23  Chennai Super Kings
# 385  386    2013         Chennai  2013-04-06       Mumbai Indians
# 429  430    2013          Mumbai  2013-05-05       Mumbai Indians
# ...

# %%
k= count["winner"].value_counts()
k
# Out:
# Mumbai Indians         12
# Chennai Super Kings     9
# Name: winner, dtype: int64

# %% [markdown]
# # Which team won most of the matches in mumbai?

# %%
l= df[(df["city"] == "Mumbai") & (df["winner"].notnull())]
l
# Out:
#       id  season    city        date                        team1  \
# 6      7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15    16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23    24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27    28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# ..   ...     ...     ...         ...                          ...
# 572  573    2015  Mumbai  2015-05-19               Mumbai Indians
# 576  577    2016  Mumbai  2016-04-09               Mumbai Indians
# 584  585    2016  Mumbai  2016-04-16               Mumbai Indians
# 589  590    2016  Mumbai  2016-04-20  Royal Challengers Bangalore
# 599  600    2016  Mumbai  2016-04-28        Kolkata Knight Riders
#
#                        team2       toss_winner toss_decision  result  \
# 6             Mumbai Indians    Mumbai Indians         field  normal
# ...

# %%
m= l["winner"].value_counts()
m
# Out:
# Mumbai Indians                 45
# Chennai Super Kings             8
# Kings XI Punjab                 5
# Royal Challengers Bangalore     5
# Rajasthan Royals                5
# Deccan Chargers                 3
# Kolkata Knight Riders           3
# Pune Warriors                   3
# Rising Pune Supergiant          2
# Delhi Daredevils                2
# Kochi Tuskers Kerala            1
# Sunrisers Hyderabad             1
# Rising Pune Supergiants         1
# Gujarat Lions                   1
# Name: winner, dtype: int64

# %% [markdown]
# # How many times each team won the toss and won the match in mumbai

# %%
l= df[(df["city"] == "Mumbai") & (df["winner"].notnull())]
l
# Out:
#       id  season    city        date                        team1  \
# 6      7    2017  Mumbai  2017-04-09        Kolkata Knight Riders
# 9     10    2017  Mumbai  2017-04-12          Sunrisers Hyderabad
# 15    16    2017  Mumbai  2017-04-16                Gujarat Lions
# 23    24    2017  Mumbai  2017-04-22               Mumbai Indians
# 27    28    2017  Mumbai  2017-04-24       Rising Pune Supergiant
# ..   ...     ...     ...         ...                          ...
# 572  573    2015  Mumbai  2015-05-19               Mumbai Indians
# 576  577    2016  Mumbai  2016-04-09               Mumbai Indians
# 584  585    2016  Mumbai  2016-04-16               Mumbai Indians
# 589  590    2016  Mumbai  2016-04-20  Royal Challengers Bangalore
# 599  600    2016  Mumbai  2016-04-28        Kolkata Knight Riders
#
#                        team2       toss_winner toss_decision  result  \
# 6             Mumbai Indians    Mumbai Indians         field  normal
# ...

# %%
n = l.groupby(["toss_winner","winner"]).count()["id"]
n
# Out:
# toss_winner                  winner
# Chennai Super Kings          Chennai Super Kings             5
#                              Kings XI Punjab                 1
#                              Mumbai Indians                  1
# Deccan Chargers              Deccan Chargers                 3
#                              Kolkata Knight Riders           1
#                              Mumbai Indians                  1
#                              Royal Challengers Bangalore     1
# Delhi Daredevils             Delhi Daredevils                2
#                              Mumbai Indians                  5
#                              Rajasthan Royals                2
# Gujarat Lions                Gujarat Lions                   1
# Kings XI Punjab              Chennai Super Kings             1
#                              Mumbai Indians                  2
#                              Pune Warriors                   1
# ...

# %% [markdown]
# # Which venue hosted most number of matches

# %%
o= df["venue"].value_counts()
o
# Out:
# M Chinnaswamy Stadium                                   63
# Eden Gardens                                            61
# Feroz Shah Kotla                                        59
# Wankhede Stadium                                        57
# Rajiv Gandhi International Stadium, Uppal               49
# MA Chidambaram Stadium, Chepauk                         48
# Punjab Cricket Association Stadium, Mohali              35
# Sawai Mansingh Stadium                                  33
# Dr DY Patil Sports Academy                              17
# Subrata Roy Sahara Stadium                              17
# Maharashtra Cricket Association Stadium                 15
# Kingsmead                                               15
# Sardar Patel Stadium, Motera                            12
# SuperSport Park                                         12
# Punjab Cricket Association IS Bindra Stadium, Mohali    11
# Dr. Y.S. Rajasekhara Reddy ACA-VDCA Cricket Stadium     11
# ...

# %% [markdown]
# ## Find how many matches chennai super kings played at M Chinnaswamy stadium?

# %%
p= df[(df["venue"] == "M Chinnaswamy Stadium") & ((df["team1"] == "Chennai Super Kings") | (df["team2"] == "Chennai Super Kings"))]
p
# Out:
#       id  season       city        date                        team1  \
# 73    74    2008  Bangalore  2008-04-28          Chennai Super Kings
# 191  192    2010  Bangalore  2010-03-23  Royal Challengers Bangalore
# 301  302    2011  Bangalore  2011-05-22          Chennai Super Kings
# 378  379    2012  Bangalore  2012-05-23          Chennai Super Kings
# 451  452    2013  Bangalore  2013-05-18  Royal Challengers Bangalore
# 509  510    2014  Bangalore  2014-05-24  Royal Challengers Bangalore
# 537  538    2015  Bangalore  2015-04-22          Chennai Super Kings
#
#                            team2                  toss_winner toss_decision  \
# 73   Royal Challengers Bangalore          Chennai Super Kings           bat
# 191          Chennai Super Kings          Chennai Super Kings         field
# 301  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 378               Mumbai Indians               Mumbai Indians         field
# ...

# %%
q = p.count()["id"]
q
# Out:
# 7

# %% [markdown]
# # Who won most matches at M Chinnaswamy stadium?

# %%
r= df[(df["venue"] == "M Chinnaswamy Stadium") & (df["winner"].notnull())]
r
# Out:
#       id  season       city        date                        team1  \
# 11    12    2017  Bangalore  2017-04-14  Royal Challengers Bangalore
# 16    17    2017  Bangalore  2017-04-16       Rising Pune Supergiant
# 29    30    2017  Bangalore  2017-04-27  Royal Challengers Bangalore
# 41    42    2017  Bangalore  2017-05-05              Kings XI Punjab
# 44    45    2017  Bangalore  2017-05-07  Royal Challengers Bangalore
# ..   ...     ...        ...         ...                          ...
# 616  617    2016  Bangalore  2016-05-11  Royal Challengers Bangalore
# 619  620    2016  Bangalore  2016-05-14  Royal Challengers Bangalore
# 625  626    2016  Bangalore  2016-05-18  Royal Challengers Bangalore
# 632  633    2016  Bangalore  2016-05-24                Gujarat Lions
# 635  636    2016  Bangalore  2016-05-29          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
s = r["winner"].value_counts()
s
# Out:
# Royal Challengers Bangalore    29
# Mumbai Indians                  8
# Kolkata Knight Riders           6
# Kings XI Punjab                 5
# Chennai Super Kings             4
# Rajasthan Royals                3
# Delhi Daredevils                3
# Sunrisers Hyderabad             2
# Rising Pune Supergiant          1
# Gujarat Lions                   1
# Deccan Chargers                 1
# Name: winner, dtype: int64

# %% [markdown]
# # Matches played in each year

# %%
t=df["season"].value_counts()
t
# Out:
# 2013    76
# 2012    74
# 2011    72
# 2010    60
# 2016    60
# 2017    58
# 2008    58
# 2009    57
# 2015    57
# 2014    53
# Name: season, dtype: int64

# %% [markdown]
# # Which city hosted most number of matches in 2013

# %%
u= df[(df["season"] == 2013)]
v = u["city"].value_counts()
v
# Out:
# Kolkata       8
# Bangalore     8
# Hyderabad     8
# Delhi         8
# Chennai       8
# Pune          8
# Jaipur        8
# Mumbai        8
# Chandigarh    6
# Dharamsala    2
# Raipur        2
# Ranchi        2
# Name: city, dtype: int64

# %% [markdown]
# # lets analyse ipl season held in 2013

# %%
u = df[(df["season"] == 2013) ]
v= u["city"].value_counts()
plt.pie(v.values, labels = v.index, autopct='%1.1f%%', radius=10, labeldistance=2.6, shadow=True, frame=True, normalize=True)
plt.title("Number of matches hosted by each city in 2013")
plt.legend(prop={'size': 6})
plt.show()

# %% [markdown]
# # Here we will create yearwise groups

# %%
w = df.groupby("season")
x = w.size()
x
# Out:
# season
# 2008    58
# 2009    57
# 2010    60
# 2011    72
# 2012    74
# 2013    76
# 2014    53
# 2015    57
# 2016    60
# 2017    58
# dtype: int64

# %%
y = w.get_group(2013)
y
# Out:
#       id  season       city        date                        team1  \
# 381  382    2013    Kolkata  2013-04-03             Delhi Daredevils
# 382  383    2013  Bangalore  2013-04-04  Royal Challengers Bangalore
# 383  384    2013  Hyderabad  2013-04-05          Sunrisers Hyderabad
# 384  385    2013      Delhi  2013-04-06             Rajasthan Royals
# 385  386    2013    Chennai  2013-04-06               Mumbai Indians
# ..   ...     ...        ...         ...                          ...
# 452  453    2013  Hyderabad  2013-05-19        Kolkata Knight Riders
# 453  454    2013      Delhi  2013-05-21          Chennai Super Kings
# 454  455    2013      Delhi  2013-05-22          Sunrisers Hyderabad
# 455  456    2013    Kolkata  2013-05-24             Rajasthan Royals
# 456  457    2013    Kolkata  2013-05-26               Mumbai Indians
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %% [markdown]
# # THANK YOU!!
